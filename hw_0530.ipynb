# %%
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %%
def drawLine(image,color,linestep):
    rows,cols,dims=image.shape
    ret_img = np.unit8(image)
    
    for i in range(linestep, rows, linestep):
        for j in range(0,cols):
            for k in range(0,3):
                ret_img[i,j,k] = np.uint8(color[k])
                
    for i in range(0,rows):
        for j in range(linestep,cols,linestep):
            for k in range(0,3):
                ret_img[i,j,k] = np.uint8(color[k])
    return ret_img               

img=io.imread('fish.jpg')

color = [255,255,0]
step = 20

plt.figure(num=2,figsize=(8,8))
plt.subplot(1,2,1)
plt.title('origin image')
plt.imshow(img)

img2 = drawLine(img,color,step)

plt.subplot(1,2,2)
plt.title('lined result')
plt.imshow(img2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-514d658f8236> in <module>()
#      24 plt.imshow(img)
#      25
# ---> 26 img2 = drawLine(img,color,step)
#      27
#      28 plt.subplot(1,2,2)
#
# <ipython-input-15-514d658f8236> in drawLine(image, color, linestep)
#       1 def drawLine(image,color,linestep):
#       2     rows,cols,dims=image.shape
# ----> 3     ret_img = np.unit8(image)
#       4
#       5     for i in range(linestep, rows, linestep):
#
# AttributeError: module 'numpy' has no attribute 'unit8'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-231b3bdbb061> in <module>()
#      10 plt.imshow(img)
#      11
# ---> 12 img2 = drawLine(img,color,step)
#      13
#      14 plt.subplot(1,2,2)
#
# NameError: name 'drawLine' is not defined
