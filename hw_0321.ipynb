# %%
from skimage import io

# %%
img1 = io.imread('mt.jpg',as_grey = True)

# %%
print(type(img1))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img1.shape)
# Out:
# (1934, 1200)

# %%
io.imshow(img1)
# Out:
# C:\Users\hander0928\AppData\Local\conda\conda\envs\py35\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
io.show()
